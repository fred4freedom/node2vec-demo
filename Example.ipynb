# %% [markdown]
# # Simple Example
#
# This is a simple example to use the library to learn an embedding from the iris data set. This is a toy example, whose purpose is to demonstrate how to use the library.
#
# Note that this requires Pyspark to work (which this notebook already has)

# %% [markdown]
# ## Imports

# %%
from sklearn import cluster
from graph_embedder import Node2Vec
from graph_sampler import GraphSampler
import numpy as np
import pandas as pd

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as ptypes
from pyspark.sql import DataFrame
from pyspark.sql import Window

# %% [markdown]
# ## Setup Spark

# %%
# Spark session & context
spark = SparkSession.builder.master('local').getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# ## Setup MovieLens (Small) data in Spark

# %% [markdown]
# The data from `ratings.csv` and `movies.csv` are from the MovieLens small sample data set that can be obtained from https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
#
# More information is at https://grouplens.org/datasets/movielens/

# %%
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')

# %%
ratings_df = spark.createDataFrame(ratings)
movies_df = spark.createDataFrame(movies)

ratings_df = (
    ratings_df
    .withColumn('userIdExt', F.concat(F.lit('user_'), F.col('userId')))
    .filter(F.col('rating') >= 5)
)

print(f"Number of ratings = {ratings_df.count()}")
# Out:
# Number of ratings = 13211

# %%
ratings_df_sampled = ratings_df.sample(0.3).cache()
ratings_df_others = (
    ratings_df
    .join(
        ratings_df_sampled,
        on=['userId', 'movieId', 'rating'],
        how='left_anti'
    )
).cache()

print(f"Number of sampled ratings = {ratings_df_sampled.count()}")
print(f"Number of ratings for testing = {ratings_df_others.count()}")
# Out:
# Number of sampled ratings = 3977
# Number of ratings for testing = 9234

# %% [markdown]
# ## Create a graph from the data

# %%
# Generate the nodes
nodes = (
    ratings_df_sampled
    .select('userIdExt')
    .withColumnRenamed('userIdExt', 'node')
    .dropDuplicates()
    .union(
        ratings_df_sampled
        .select('movieId')
        .withColumnRenamed('movieId', 'node')
        .dropDuplicates()
    )
    .select('node')
).cache()

print(f"Number of nodes = {nodes.count()}")
# Out:
# Number of nodes = 2037

# %%
# Generate the edges
edges = (
    ratings_df_sampled
    .select('userIdExt', 'movieId', 'rating')
    .join(
        ratings_df
        .groupBy('userIdExt')
        .agg(F.sum('rating').alias('total_ratings')),
        on='userIdExt',
        how='inner'
    )
    .withColumn('weight', F.col('rating') / F.col('total_ratings'))
    .withColumnRenamed('userIdExt', 'start')
    .withColumnRenamed('movieId', 'end')
)
    
print(f"Number of edges = {edges.count()}")
# Out:
# Number of edges = 3977

# %% [markdown]
# ## Learn an embedding

# %%
node2vec = Node2Vec(
    num_dim = 64,                 # Number of dimensions of the resultant feature vector
    num_samples_per_node = 5,     # Number of times to sample the neighbourhood for each node
    path_len = 11,                # Length of the random walks
    return_param = 1.0,           # The smaller the return parameter relative to in-out, the more it learns structures
    inout_param = 1.0             # The smaller the in-out parameter relative to return, the more it learns communities
)

# %%
# Fit the graph
node2vec.fit(nodes, edges, verbose=True)
# Out:
# Iteration #1 / 5
# Sampling step 1 / 11
# Sampling step 2 / 11
# Sampling step 3 / 11
# Sampling step 4 / 11
# Sampling step 5 / 11
# Sampling step 6 / 11
# Sampling step 7 / 11
# Sampling step 8 / 11
# Sampling step 9 / 11
# Sampling step 10 / 11
# Sampling step 11 / 11
# Iteration #2 / 5
# Sampling step 1 / 11
# Sampling step 2 / 11
# Sampling step 3 / 11
# Sampling step 4 / 11
# Sampling step 5 / 11
# Sampling step 6 / 11
# Sampling step 7 / 11
# Sampling step 8 / 11
# Sampling step 9 / 11
# Sampling step 10 / 11
# Sampling step 11 / 11
# Iteration #3 / 5
# Sampling step 1 / 11
# Sampling step 2 / 11
# Sampling step 3 / 11
# Sampling step 4 / 11
# Sampling step 5 / 11
# Sampling step 6 / 11
# Sampling step 7 / 11
# Sampling step 8 / 11
# Sampling step 9 / 11
# Sampling step 10 / 11
# Sampling step 11 / 11
# Iteration #4 / 5
# Sampling step 1 / 11
# Sampling step 2 / 11
# Sampling step 3 / 11
# Sampling step 4 / 11
# Sampling step 5 / 11
# Sampling step 6 / 11
# Sampling step 7 / 11
# Sampling step 8 / 11
# Sampling step 9 / 11
# Sampling step 10 / 11
# Sampling step 11 / 11
# Iteration #5 / 5
# Sampling step 1 / 11
# Sampling step 2 / 11
# Sampling step 3 / 11
# Sampling step 4 / 11
# Sampling step 5 / 11
# Sampling step 6 / 11
# Sampling step 7 / 11
# Sampling step 8 / 11
# Sampling step 9 / 11
# Sampling step 10 / 11
# Sampling step 11 / 11

# %%
# Get the embeddings
embedding_df = node2vec.transform(nodes)
print(f"Number of embeddings = {embedding_df.count()}")
# Out:
# Number of embeddings = 2037

# %% [markdown]
# ## Recommendation
#
# Try recommending some movies

# %%
def get_user_ratings(user, ratings_df=ratings_df, movies_df=movies_df):
    df = (
        ratings_df
        .filter(F.col('userId') == user)
        .join(
            movies_df
            .select('movieId', 'title'),
            on='movieId',
            how='left'
        )
    ).toPandas()
    
    return df

# %%
def get_similar_movies(movieId, n=5, embedding_df=embedding_df, movies_df=movies_df):
    @F.udf(ptypes.FloatType())
    def similarity(x, y):
        import numpy as np
        x = np.array(x)
        y = np.array(y)
        z = np.linalg.norm(x)
        if z > 0:
            x /= z
        z = np.linalg.norm(y)
        if z > 0:
            y /= z
        z = x.dot(y)
        return float(z)
    
    df_movies = (
        embedding_df
        .filter(F.col('feature').isNotNull())
        .join(
            movies_df
            .withColumnRenamed('movieId', 'node'),
            on='node',
            how='left_semi'
        )
    )

    df_movies = (
        df_movies
        .withColumnRenamed('node', 'movieId')
        .withColumnRenamed('feature', 'movieFeature')
    )
    
    df_node = (
        embedding_df
        .filter(F.col('node') == str(movieId))
        .withColumnRenamed('node', 'movieId_search')
        .withColumnRenamed('feature', 'searchFeature')
    ).cache()
    
    df = (
        df_node
        .crossJoin(df_movies)
        .withColumn('score', similarity('searchFeature', 'movieFeature'))
        .withColumn('rank', F.row_number().over(Window.orderBy(F.col('score').desc())))
        .drop('searchFeature')
        .drop('movieFeature')
        .join(
            movies_df
            .select('movieId', 'title'),
            on='movieId',
            how='left'
        )
    )
    
    if n:
        df = (
            df
            .filter(F.col('rank') <= n)
        )

    return df.toPandas().sort_values('score', ascending=False)

# %%
def get_user_recommendations(user, n=5, ratings_df=ratings_df_sampled, embedding_df=embedding_df, movies_df=movies_df):
    @F.udf(ptypes.FloatType())
    def similarity(x, y):
        import numpy as np
        x = np.array(x)
        y = np.array(y)
        z = np.linalg.norm(x)
        if z > 0:
            x /= z
        z = np.linalg.norm(y)
        if z > 0:
            y /= z
        z = x.dot(y)
        return float(z)
    
    df_movies = (
        embedding_df
        .filter(F.col('feature').isNotNull())
        .join(
            movies_df
            .withColumnRenamed('movieId', 'node'),
            on='node',
            how='left_semi'
        )
    )
    
    if ratings_df:
        df_movies = (
            df_movies
            .join(
                ratings_df
                .filter(F.col('userId') == user)
                .withColumnRenamed('movieId', 'node'),
                on='node',
                how='left_anti'
            )
        ).cache()
        
    df_movies = (
        df_movies
        .withColumnRenamed('node', 'movieId')
        .withColumnRenamed('feature', 'movieFeature')    
    )
    
    df_user = (
        embedding_df
        .filter(F.col('node') == 'user_' + str(user))
        .withColumnRenamed('node', 'userIdExt')
        .withColumnRenamed('feature', 'userFeature')
    ).cache()
    
    df = (
        df_user
        .crossJoin(df_movies)
        .withColumn('score', similarity('userFeature', 'movieFeature'))
        .withColumn('rank', F.row_number().over(Window.partitionBy('userIdExt').orderBy(F.col('score').desc())))
        .drop('userFeature')
        .drop('movieFeature')
        .join(
            movies_df
            .select('movieId', 'title'),
            on='movieId',
            how='left'
        )
    )
    
    if n:
        df = (
            df
            .filter(F.col('rank') <= n)
        )

    return df.toPandas().sort_values('score', ascending=False)

# %% [markdown]
# First user

# %%
# What the user gave ratings (in training data)
display(get_user_ratings(25, ratings_df=ratings_df_sampled))
# Out:
#    movieId  userId  rating   timestamp userIdExt  \
# 0    91529      25     5.0  1535470498   user_25
# 1      260      25     5.0  1535470429   user_25
# 2   122912      25     5.0  1535470461   user_25
# 3     4993      25     5.0  1535470421   user_25
# 4    79132      25     5.0  1535470428   user_25
# 5   116797      25     5.0  1535470507   user_25
# 6   187593      25     5.0  1535470534   user_25
#
#                                                title
# 0                      Dark Knight Rises, The (2012)
# 1          Star Wars: Episode IV - A New Hope (1977)
# 2             Avengers: Infinity War - Part I (2018)
# 3  Lord of the Rings: The Fellowship of the Ring,...
# 4                                   Inception (2010)
# 5                          The Imitation Game (2014)
# 6                                  Deadpool 2 (2018)

# %%
# What the user gave a ratings (not in training data)
display(get_user_ratings(25, ratings_df=ratings_df_others))
# Out:
#     movieId  userId  rating   timestamp userIdExt  \
# 0     60069      25     5.0  1535470523   user_25
# 1     68157      25     5.0  1535470515   user_25
# 2      7153      25     5.0  1535470418   user_25
# 3     68954      25     5.0  1535470493   user_25
# 4    180095      25     5.0  1535470476   user_25
# 5      2571      25     5.0  1535470427   user_25
# 6    177593      25     5.0  1535470532   user_25
# 7      1198      25     5.0  1535470495   user_25
# 8      3578      25     5.0  1535470497   user_25
# 9      2028      25     5.0  1535470505   user_25
# 10      527      25     5.0  1535470432   user_25
# 11    58559      25     5.0  1535470524   user_25
# 12     5952      25     5.0  1535470419   user_25
#
#                                                 title
# 0                                       WALL·E (2008)
# 1                         Inglourious Basterds (2009)
# 2   Lord of the Rings: The Return of the King, The...
# 3                                           Up (2009)
# 4                                       Wonder (2017)
# 5                                  Matrix, The (1999)
# 6    Three Billboards Outside Ebbing, Missouri (2017)
# 7   Raiders of the Lost Ark (Indiana Jones and the...
# 8                                    Gladiator (2000)
# 9                          Saving Private Ryan (1998)
# 10                            Schindler's List (1993)
# 11                            Dark Knight, The (2008)
# 12      Lord of the Rings: The Two Towers, The (2002)

# %%
# Recommended movies
display(
    get_user_recommendations(25, n=20, ratings_df=ratings_df_sampled, embedding_df=embedding_df)
)
# Out:
#    movieId userIdExt     score  rank  \
# 14   59784   user_25  0.692618     1
# 17    6650   user_25  0.691941     2
# 12   62336   user_25  0.679376     3
# 9     7143   user_25  0.673626     4
# 11    5971   user_25  0.666631     5
# 0      222   user_25  0.650476     6
# 3    57504   user_25  0.644588     7
# 6   103772   user_25  0.624740     8
# 8     2924   user_25  0.624474     9
# 4    31696   user_25  0.592547    10
# 2   150548   user_25  0.573238    11
# 1   102445   user_25  0.560503    12
# 19   58559   user_25  0.541902    13
# 7    34405   user_25  0.540344    14
# 5   111362   user_25  0.537213    15
# 15   55442   user_25  0.532550    16
# 13    6365   user_25  0.526285    17
# 16   45722   user_25  0.523168    18
# 10    6942   user_25  0.519447    19
# 18  140627   user_25  0.516984    20
#
#                                                 title
# 14                               Kung Fu Panda (2008)
# 17                    Kind Hearts and Coronets (1949)
# 12                                        FLCL (2000)
# 9                            Last Samurai, The (2003)
# 11       My Neighbor Totoro (Tonari no Totoro) (1988)
# 0                            Circle of Friends (1995)
# 3   Girl Who Leapt Through Time, The (Toki o kaker...
# 6                               Wolverine, The (2013)
# 8                    Drunken Master (Jui kuen) (1978)
# 4                                  Constantine (2005)
# 2               Sherlock: The Abominable Bride (2016)
# 1                      Star Trek Into Darkness (2013)
# 19                            Dark Knight, The (2008)
# 7                                     Serenity (2005)
# 5                   X-Men: Days of Future Past (2014)
# 15                                  Persepolis (2007)
# 13                        Matrix Reloaded, The (2003)
# 16  Pirates of the Caribbean: Dead Man's Chest (2006)
# 10                               Love Actually (2003)
# 18                       Battle For Sevastopol (2015)

# %% [markdown]
# User 25 is recommended the movie `The Dark Knight (2008)`, which also appears in the testing set. He is also recommended `X-Men` and `Matrix` movies which are similar to what he seems to like

# %% [markdown]
# Find similar movies

# %%
# Find the movie id
movies = (
    movies_df
    .filter(F.col('title').contains('Love Actually'))
).collect()

movieTitle = movies[0]['title']
movieId = movies[0]['movieId']

print(f"ID: {movieId} Title: {movieTitle}")

display(
    get_similar_movies(movieId, n=5, embedding_df=embedding_df)
)
# Out:
# ID: 6942 Title: Love Actually (2003)
#   movieId movieId_search     score  rank  \
# 0    6942           6942  1.000000     1
# 3   66371           6942  0.898201     2
# 4    5646           6942  0.876703     3
# 2   31658           6942  0.869262     4
# 1   62336           6942  0.862730     5
#
#                                                title
# 0                               Love Actually (2003)
# 3                      Departures (Okuribito) (2008)
# 4                                     Valmont (1989)
# 2  Howl's Moving Castle (Hauru no ugoku shiro) (2...
# 1                                        FLCL (2000)

# %% [markdown]
# These movies are about love and relationships
